# %%
## Roman Empire ( 46 B.C). The game is partially based on the history of the Roman Empire. 
#This game is about finding Cleopatra who ruled in Egypt since 51 B.C.The user should begin the game with a specific name. The user has to be Julius Caesar. Julius Caesar was a celebrated conqueror of the Roman world. 
#There are 5 regions: Hispania, Gaul, Moesia, Germania and Egipt. 
#Julius Caesar attempts to find Cleopatra and to find her, he travels to all regions. 
#Each region has specific information that leads the user to lose if they choose the wrong direction.


name= ""
while name != "Julio Cesar" :
 name = input("Enter your name: ")
print("Hello Julio Cesar, I hope you are ready to find Cleopatra")
print("Your journey from Rome is dangerous but I hope you can find Cleopatra")
print("Departure location: Rome")

direction = ("North-Germania, East- Moesia, West- Hispania, North- West Gaul, South-Egipt")
print("46 B.C")
print("You are in Rome now, please get ready for departure. The Roman Empire is expanding, Romans have many enemies in Germania and Gaul, the Lousitanian tribes in Hispania and the  Dacius tribes in Moesia")
   
decision1=""
decision2=""
decision3=""
decision4=""
decision5=""
total = 5


def exit(travel):
  print("\n")
  print("Start again")
decision1 =""
print("Press ((yes) if you want to find Cleopatra in Germania and (escape) if you prefer to go to Hispania")
decision1= input("Do you want to go to Germania?")
if decision1 == ("yes"):
  print("Barbarians are waiting for you, I would advice you to be ready to fight. " )
else:
  print("Good luck finding her ")
  print("You decide to go to Hispania")
  
while decision1:
    decision1 = input("Do you want to fight?")
    print()
    if decision1 == "yes" : 
      print(" You were attacked by a warrior wielding a sword.You have many injuries ")
      exit("")
      
    
      break

    else: 
     print("You escape, someone tells you that Cleopatra is not in Germania. You leave Germania ")
     break
    
    


decision2 =""
print("Press ((yes) if you want to find Cleopatra in Hispania and (escape) if you prefer to go to Gaul")
decision2= input("Do you want to go to Hispania? ")
if decision2 == ("yes") : 
  print("A friend of yours tells you that he saw Cleopatra but he does not know where she is. You start looking for her")
else:
  print("Good luck finding her ")
  print("You decide to go to Gaul")

while decision2:
    decision2 = input("Do you want to stay?")
    print()
    if  decision2 == "yes" : 
      print("Cleopatra is not here you spend many weeks in Hispania and Rome asks you to come back. You could not find Cleopatra here")
      exit("")
      break

    else:
     print(" General Cayo has heard that Cleopatra is in Gaul")
  
     break

decision3= ""
print("Press ((yes) if you want to find Cleopatra in Gaul and (escape) if you prefer to go to Moesia")
decision3= input(" Do you want to go to Gaul?")
if decision3 == ("yes") :
   print("Vercingetorix does not want you here. You need to escape. You escape and you need to choose to go to Dacia or Dalmacia")
else:
  print("Good luck finding her ")
  print("You need to choose your next destinario: Egipt or Moesia")
while decision3:
      decision3 = input(" Do you want to go to Dacia?")
      print()
      if decision3 == "yes": 
         print("You encounter Barbarians In Dacia, you are held hostage ")
         exit("")

         break
      else:
         print("You decide to go to Dalmacia and from there you take a boat")
         break

decision4=""
print("Press ((yes) if you want to find Cleopatra in Moesia and (escape) if you prefer to go to Egipt")
decision4= input("Do you want to go to Moesia? ")  
if decision4== ("yes") : 
   print("Moesia has been conquered by Romans, you are safe. However; your friend Bruto tells you that Clepatra was kidnapped and held for ransom and your friend Marco Antonio tells you that Cleopatra went to Egypt")
else:
   print("It looks she is in Egypt")
   print("You decide to go to Egypt")
while decision4:
      decision4 = input("Do you believe Bruto? ")
      print()
      if decision4 == "yes" :
       print("Bruto is plotting against you. You spend all your money rescuing someone who is not Cleopatra. You have to come back to Rome" )
       exit("")
       break
      else:
       print("You go to Egipt")
       break
  
decision5= ""
print("Press ((yes) if you want to find Cleopatra in Egypt and (escape) if you prefer to go to another place")
decision5= input(" Do you want to go to Egypt?")
if decision5 == ("yes") :
   print("Cleopatra is in Egypt, his brother Ptolomeo called her. Now, you do not know if she is in the city of Alexandria or fighting against the Hyksos in the Northern Egypt")
else:
  print("She is in Egipt ")
  print("you lose")

while decision5:
      decision5 = input(" Do you want to go to the city of Alexandria?")
      print()
      if decision5 == "yes": 
         print("You win, you finally found her. You can go back to Rome together ")
         

         break
      else:
         print("You decide to go to Northern Egypt but cleopatra is not here . The Hyksos capture you. You lose. ")
         exit("")
         break
